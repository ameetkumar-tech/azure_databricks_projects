# %%
df = spark.read.csv('/Volumes/workspace/default/my_files/Employee.csv', header=True, inferSchema=True)

# %%
df.show()

# %%
display(df)

# %%
df.printSchema()

# %%
df.select(df.Emp_ID, df.Name, df.Salary).show()

# %%
df.select(df.columns[1:10]).show()
