# %%
df = spark.read.csv('/Volumes/workspace/default/my_files/Employee.csv',header=True,inferSchema=True)

# %%
df.show()

# %%
df.groupBy("Address").count().show()

# %%
df.groupBy("Dept_ID").mean().show()

# %%
df.groupBy("Dept_ID").max("Salary").show()

# %%
df.groupBy("Dept_ID").min("Salary").show()

# %%
df.groupBy("Dept_ID").sum("Salary").show()

# %%
df.groupBy("Address").avg("Salary").alias("Average Salary").show()
