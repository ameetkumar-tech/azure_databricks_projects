# %%
df = spark.read.csv('/Volumes/workspace/default/my_files/Employee.csv',header=True,inferSchema=True)

# %%
df.show()

# %%
df.filter(df.Address=="India").show()

# %%
df.filter(df.Address!="India").show()

# %%
df.filter(df.Salary>10000).show()

# %%
df.filter(df.Salary<20000).show()

# %%
df.filter((df.Name=="Ameet") & (df.Salary==10000)).show()

# %%
#df.filter((df.Name=="Ameet") | (df.Name=="Rinku")).show()
df.filter((df.Name=="Ameet") | (df.Salary==6000)).show()

# %%
df.filter(df.Name.startswith("A")).show()

# %%
df.filter(df.Name.endswith("i")).show()

# %%
df.filter(df.Name.like("%a%")).show()
