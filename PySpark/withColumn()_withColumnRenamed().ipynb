# %%
df = spark.read.csv('/Volumes/workspace/default/my_files/Employee.csv',header=True)

# %%
df.show()

# %%
df.withColumn("salary1",df.Salary*2).show()

# %%
from pyspark.sql.functions import lit
df.withColumn("Country",lit(("usa"))).show()

# %%
df.withColumn("increment",lit(0)).show()

# %%
from pyspark.sql.functions import col
df1 = df.withColumn("Salary",col("Salary").cast("integer"))

# %%
df1.show()

# %%
df1.printSchema()

# %%
df.withColumnRenamed("Address","Country").show()
