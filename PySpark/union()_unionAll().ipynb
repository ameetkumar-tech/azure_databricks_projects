# %%
import pyspark 
from pyspark.sql import SparkSession

data1 = [("James","Sales","NY",90000,34,10000), \
    ("Michael","Sales","NY",86000,56,20000), \
    ("Robert","Sales","CA",81000,30,23000), \
    ("Maria","Finance","CA",90000,24,23000) \
  ]
columns= ["employee_name","department","state","salary","age","bonus"]
df1 = spark.createDataFrame(data=data1, schema = columns)
df1.show()

# %%
data2 = [("James","Sales","NY",99000,34,10000), \
    ("Maria","Finance","CA",99000,24,23000), \
    ("Jen","Finance","NY",83000,53,15000), \
    ("Jeff","Marketing","CA",79000,25,18000), \
    ("Kumar","Marketing","NY",60000,50,21000)
    ]
columns2 = ["employee_name","department","state","salary","bonus"]
df2 = spark.createDataFrame(data=data2, schema = columns2 )
df2.show()

# %%
df1.union(df2).show()

# %%
df1.unionAll(df2).show()

# %%
df1.union(df2).distinct().show()
