# %%
#df_employee = spark.read.csv('/Volumes/workspace/default/my_files/employee_join_databricks.csv',header=True,inferSchema=True)

df_dept = spark.read.csv('/Volumes/workspace/default/my_files/department_join_databricks.csv',header=True,inferSchema=True)

# %%
#df_employee.show()

df_dept.show()

# %%
df_employee.join(df_dept,df_employee.emp_id==df_dept.user_id,'inner').show()

# %%
df_employee.join(df_dept,df_employee.emp_id==df_dept.user_id,'left').show()

# %%
df_employee.join(df_dept,df_employee.emp_id==df_dept.user_id,'right').show()

# %%
df_employee.join(df_dept,df_employee.emp_id==df_dept.user_id,'fullouter').show()

# %%
df_employee.join(df_dept,df_employee.emp_id==df_dept.user_id,'leftsemi').show()

# %%
df_employee.join(df_dept,df_employee.emp_id==df_dept.user_id,'leftanti').show()
