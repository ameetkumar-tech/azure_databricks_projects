# %%
data = [(1,'manish',1000),(2,'rani',5000),(3,'sita',2000),(4,'ram',3000 )]
columns = ['id','name','salary']

df = spark.createDataFrame(data,columns)
df.show()

# %%
df.createOrReplaceTempView("temp_view")

# %%
# %sql
select * from temp_view
