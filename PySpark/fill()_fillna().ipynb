# %%
df = spark.read.csv('/Volumes/workspace/default/my_files/null_data.csv',header=True,inferSchema=True)

# %%
df.show()

# %%
df.na.fill("").show()

# %%
df.na.fill(0).show()

# %%
df.fillna("").show()

# %%
df.na.fill("No_Data",['type','city']).na.fill(0,["zipcode","population"]).show()
