# %%
df = spark.read.csv('/Volumes/workspace/default/my_files/emp_data.csv',header=True,inferSchema=True)

# %%
df.show()

# %%
df.sort("emp_id","name").show()

# %%
df.sort("salary").show()

# %%
df.sort(df.salary.desc()).show()

# %%
df.sort(df.name.desc()).show()

# %%
df.orderBy(df.name.desc(),df.salary.desc()).show()
